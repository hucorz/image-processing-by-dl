# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %%
import torch
print(torch.__version__)
# Out:
# 1.11.0+cu113

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/image-processing-by-dl/Faster_RCNN

# %%
# !mkdir data
# !tar -xvf ./drive/MyDrive/image-processing-by-dl/data/VOC/VOCtrainval_11-May-2012.tar -C ./data/
# Out:
# tar: ./drive/MyDrive/image-processing-by-dl/data/VOC/VOCtrainval_11-May-2012.tar: Cannot open: No such file or directory
# tar: Error is not recoverable: exiting now

# %%
# %cp ./drive/MyDrive/image-processing-by-dl/data/VOC/split_data.py ./data/
# %cd ./data
# !python ./split_data.py
# %cd ../
# Out:
# /content/data
# /content

# %%
# %cd ./drive/MyDrive/image-processing-by-dl/Faster_RCNN/
# !python change_backbone_with_fpn.py --data-path ../../../../data/
# Out:
# [Errno 2] No such file or directory: './drive/MyDrive/image-processing-by-dl/Faster_RCNN/'
# /content/drive/MyDrive/image-processing-by-dl/Faster_RCNN
# Namespace(amp=False, aspect_ratio_group_factor=3, batch_size=8, data_path='../../../../data/', device='cuda:0', epochs=10, lr=0.005, momentum=0.9, num_classes=20, output_dir='./save_weights', resume='', start_epoch=0, weight_decay=0.0001)
# Using cuda device training.
# Using [0, 0.5, 0.6299605249474366, 0.7937005259840997, 1.0, 1.2599210498948732, 1.5874010519681994, 2.0, inf] as bins for aspect ratio quantization
# Count of instances per bin: [   5   25  929  117  260 4198  135   48]
# Using 2 dataloader workers
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...
